# %% [markdown]
# # Atividade Prática II - Treinamento e Validação de Modelos de RL
#
# **Aluno:** Recigio Poffo
#
# **Disciplina:** Reinforcement Learning - Turma I
#
# **Data:** 03/07/2021
#
#
#
# Neste trabalho vamos aplicar `Gym`, `Stable-Baselines3` e `RL Baselines Zoo` para lidar com o treinamento e validação de problemas de aprendizado por reforço. Sua tarefa é:
#
# 1. Selecionar um cenário da biblioteca `Gym` de sua preferência, desde que este cenário também seja contemplado pelos modelos disponibilizados na `rl baselines zoo`;
# 2. Selecionar três algoritmos das biblioteca `Stable-baselines3` para resolver esse problema. Pesquise na documentação da biblioteca quais são os algoritmos mais adequados para o ambiente escolhido e justifique a sua escolha.
# 3. Realize o treinamento de cada um dos três modelos ---você pode ajustar os parâmetros do modelos, se achar necessário--- e salve os modelos em disco.
# 4. De posse dos modelos treinados e salvos, carregue-os e avalie-os por 10 episódios. Apresente os resultados médios e gere a curva de recompensa acumulada disponibilizada pelo `TensorBoard`.
# 5. Compare os resultados dos modelos treinados com os resultados obtidos por modelo(s) existentes no `RL Baselines Zoo` para o cenário escolhido.
# 6. Gere um vídeo do melhor modelo que você treinou e do modelo escolhido na `RL Baselines Zoo`. Verifique a documentação de cada biblioteca sobre a criação do vídeo e visualização em Notebooks.
#
#
#
# * **Data de entrega:** 16/07/2021
# * **Local de envio:** AVA.
# * **Tipo de documento:** Notebook (`.ipynb`).

# %% [markdown]
# ### Testando ambiente base

# %%
#importa a biblioteca gym
import gym
import time


scenario = 'BeamRiderNoFrameskip-v4'
env = gym.make(scenario)

observation = env.reset()
#define a quantidade de passos de tempo
for _ in range(100):
  #desenha a visualização do ambiente  
  env.render()
  #toma uma ação de forma aleatória
  action = env.action_space.sample()
  #observa o ambiente com a base na ação executada
  observation, reward, done, info = env.step(action)
  #adiciona um atraso na execução para melhorar a visualização
  time.sleep(0.03)
  #verifica se o agente completou a tarefa
  if done:
    #reinicia a simulação
    observation = env.reset()
#fecha a visualização
env.close()

# %%
from IPython.display import Image

# %% [markdown]
# ### Escolhendo os modelos
#
# #### Foi escolhido o ambiente BeamRiderNoFrameskip-v4
#
# #### Foram escolhidos os modelos A2C, PPO,DQN. Foram utilizados estes por que eles funcionam razoavelmente diferentes pelo que eu pesquisei na documentação do https://stable-baselines3.readthedocs.io/en/master/.
#
#
# #### A2C: https://openai.com/blog/baselines-acktr-a2c/
# #### PPO: https://openai.com/blog/openai-baselines-ppo/
# #### DQN: https://www.nature.com/articles/nature14236
#
# #### O A2C é baseado no A3C e faz uso de multiplos trabalhadores tendêndeciando ao gradiente natural. O PPO, que é um algoritmo que tenta resolver problema scom gradientes descendentes, que podem demorar muito ou serem dificeis de achar um "tunning" ideal. Por fim, o DQN, que tem como base o Q-Learning, mais especificamente a versão "Neural Fitted Q Iteration"

# %%
#tensorboard --logdir /tmp/stable-baselines/

# %% [markdown]
# ### Considerações Iniciais

# %%
#Para o modelo gerar a saida de dados de eval no tensor flow, a unica forma que encontrei foi criar dois ambientes,
#um de treinamento e outro e avaliação. Além disso, precisei setar a frequência do eval e o numero de episodios.
#coloquei apenas 1 avaliação por que acredito que o simulador ficava "parado", como explico melhor mais adiante e 
#demorava muito para continuaro treinamento. Treinamento feito inicialmente no 2e6, com mesmo numero para comparar no ZOO

# %% [markdown]
# ### A2C

# %%
import gym
import time
from stable_baselines3 import A2C

#carrega o ambiente
env_a2c = gym.make('BeamRiderNoFrameskip-v4')
eval_env_a2c = gym.make('BeamRiderNoFrameskip-v4')

#instancia o algoritmo de aprendizagem
model = A2C('MlpPolicy', env_a2c, verbose=1,create_eval_env=True,tensorboard_log="/tmp/stable-baselines/BeamRiderNoFrameskip-v4/custon_a2c")

#treina o algoritmo por 2e5 passos de tempo
model.learn(total_timesteps=int(2e6),eval_env=eval_env_a2c,eval_freq=200000, n_eval_episodes=1)

# %% [markdown]
# #### Visualização do primeiro resultado

# %%
import time

for _ in range(2):
    obs = env_a2c.reset()
    for i in range(1000):
        action, _states = model.predict(obs, deterministic=True)
        obs, rewards, done, info = env_a2c.step(action)
        time.sleep(0.003)
        env_a2c.render()
        
env_a2c.close()
# Out:
# c:\xampp\htdocs\posfurb\aprendizadodemaquina\python\.env\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Não é possível alterar o modo de thread depois de o mesmo estar definido
#   warnings.warn(str(err))

# %%
env_a2c.close()

# %% [markdown]
# #### Salvamento, carregamento e avaliação do modelo

# %%
# Salva o agente
model.save("modelos/a2c/recigio_beamrider2M")

# %%
# deleta o agente/modelo
del model

# %%
# carrega um modelo já treinado
model = A2C.load("modelos/a2c/recigio_beamrider2M", env=env_a2c)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
# importando biblioteca de avaliação e avaliando por 10 episodios
from stable_baselines3.common.evaluation import evaluate_policy

mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10, render=True,)

# %%
print(mean_reward)
print(std_reward)
# Out:
# 660.0
# 0.0

# %% [markdown]
# ### PPO

# %%
import gym
import time
from stable_baselines3 import PPO

#carrega o ambiente
env_ppo = gym.make('BeamRiderNoFrameskip-v4')
eval_env_ppo = gym.make('BeamRiderNoFrameskip-v4')

#instancia o algoritmo de aprendizagem
model2 = PPO('MlpPolicy', env_ppo, verbose=1,create_eval_env=True,tensorboard_log="/tmp/stable-baselines/BeamRiderNoFrameskip-v4/custon_ppo")

#treina o algoritmo por 2e5 passos de tempo
model2.learn(total_timesteps=int(2e6),eval_env=eval_env_ppo,eval_freq=200000, n_eval_episodes=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to /tmp/stable-baselines/BeamRiderNoFrameskip-v4/custon_ppo\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 397  |
# |    iterations      | 1    |
# |    time_elapsed    | 5    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 2            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0107437195 |
# |    clip_fraction        | 0.0756       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.00418      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12           |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00827     |
# |    value_loss           | 12.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.67e+03    |
# |    ep_rew_mean          | 308         |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 3           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010442991 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | -0.0216     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 33.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.67e+03    |
# |    ep_rew_mean          | 308         |
# | time/                   |             |
# |    fps                  | 152         |
# |    iterations           | 4           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010710519 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | -0.023      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.94        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 18.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.67e+03    |
# |    ep_rew_mean          | 308         |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 5           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011611038 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.0158      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.61        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 28.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.24e+03    |
# |    ep_rew_mean          | 352         |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 6           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013553574 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | -0.0816     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 13.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.24e+03    |
# |    ep_rew_mean          | 352         |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 7           |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017913658 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | -0.0153     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.52        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 5.84        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.24e+03   |
# |    ep_rew_mean          | 352        |
# | time/                   |            |
# |    fps                  | 136        |
# |    iterations           | 8          |
# |    time_elapsed         | 119        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00871405 |
# |    clip_fraction        | 0.0903     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.13      |
# |    explained_variance   | -0.0328    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.6       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0135    |
# |    value_loss           | 31.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.55e+03    |
# |    ep_rew_mean          | 381         |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 9           |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010391725 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | -0.0424     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29          |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 36.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.55e+03    |
# |    ep_rew_mean          | 381         |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 10          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011470506 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | -0.000861   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.7        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 27.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.55e+03    |
# |    ep_rew_mean          | 381         |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 11          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010906251 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | -0.0306     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.4        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 46          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.03e+03    |
# |    ep_rew_mean          | 451         |
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 12          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012938651 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | -0.0212     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.5         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 15.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.03e+03   |
# |    ep_rew_mean          | 451        |
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 13         |
# |    time_elapsed         | 203        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01042504 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.09      |
# |    explained_variance   | 0.0178     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.9       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0159    |
# |    value_loss           | 20.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.03e+03    |
# |    ep_rew_mean          | 451         |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 14          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016431581 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | -0.0677     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.04        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 15.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.04e+03    |
# |    ep_rew_mean          | 414         |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 15          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012658412 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.00324     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00836    |
# |    value_loss           | 7.83        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.04e+03    |
# |    ep_rew_mean          | 414         |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 16          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011341643 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | -0.0136     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.8        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 15.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.04e+03     |
# |    ep_rew_mean          | 414          |
# | time/                   |              |
# |    fps                  | 128          |
# |    iterations           | 17           |
# |    time_elapsed         | 271          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0091001615 |
# |    clip_fraction        | 0.0792       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.06        |
# |    explained_variance   | -0.0126      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.7         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0138      |
# |    value_loss           | 37.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.14e+03    |
# |    ep_rew_mean          | 455         |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 18          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012314619 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | 0.00199     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 29.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.14e+03    |
# |    ep_rew_mean          | 455         |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 19          |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011079916 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | -0.00857    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.2        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 43.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.14e+03   |
# |    ep_rew_mean          | 455        |
# | time/                   |            |
# |    fps                  | 127        |
# |    iterations           | 20         |
# |    time_elapsed         | 320        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01495009 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.06      |
# |    explained_variance   | -0.031     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.63       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0142    |
# |    value_loss           | 13.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.14e+03    |
# |    ep_rew_mean          | 455         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 21          |
# |    time_elapsed         | 338         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.014205655 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | -0.0521     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20          |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 22.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.23e+03    |
# |    ep_rew_mean          | 446         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 22          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.016324207 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | -0.00694    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 29.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.23e+03    |
# |    ep_rew_mean          | 446         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 23          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012567597 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.0109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 30.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.23e+03    |
# |    ep_rew_mean          | 446         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 24          |
# |    time_elapsed         | 386         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.015080372 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.00801     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.9        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 22.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.19e+03    |
# |    ep_rew_mean          | 451         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 25          |
# |    time_elapsed         | 402         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010421681 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | -0.00656    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.7        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 30.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.19e+03    |
# |    ep_rew_mean          | 451         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 26          |
# |    time_elapsed         | 418         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.020538274 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | -0.00147    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11          |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 22          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.09e+03    |
# |    ep_rew_mean          | 425         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 27          |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.016253322 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | -0.0725     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 15.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.09e+03    |
# |    ep_rew_mean          | 425         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 28          |
# |    time_elapsed         | 450         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.019222863 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.0192     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.48        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 8.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.09e+03    |
# |    ep_rew_mean          | 425         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 29          |
# |    time_elapsed         | 466         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.014019111 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.00436     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.734       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 15.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.09e+03    |
# |    ep_rew_mean          | 425         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 30          |
# |    time_elapsed         | 483         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.012168948 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | -0.0118     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.522       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 15.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.27e+03     |
# |    ep_rew_mean          | 427          |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 31           |
# |    time_elapsed         | 499          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0108986115 |
# |    clip_fraction        | 0.086        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.0229      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.3         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00847     |
# |    value_loss           | 36.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.27e+03    |
# |    ep_rew_mean          | 427         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 32          |
# |    time_elapsed         | 515         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.017706618 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.00032    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.82        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 15.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.06e+03   |
# |    ep_rew_mean          | 404        |
# | time/                   |            |
# |    fps                  | 126        |
# |    iterations           | 33         |
# |    time_elapsed         | 532        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01579294 |
# |    clip_fraction        | 0.241      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.91      |
# |    explained_variance   | -0.00617   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.59       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00863   |
# |    value_loss           | 7.56       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.06e+03     |
# |    ep_rew_mean          | 404          |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 34           |
# |    time_elapsed         | 548          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0152967125 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.00984      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.14         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0121      |
# |    value_loss           | 30.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.06e+03    |
# |    ep_rew_mean          | 404         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 35          |
# |    time_elapsed         | 565         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013223066 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | -0.0243     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0293      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 8.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.06e+03    |
# |    ep_rew_mean          | 404         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 36          |
# |    time_elapsed         | 581         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012954321 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | -0.00751    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.49        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 23.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.06e+03    |
# |    ep_rew_mean          | 404         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 37          |
# |    time_elapsed         | 599         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011057784 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.00356     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.3        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 50.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.06e+03   |
# |    ep_rew_mean          | 404        |
# | time/                   |            |
# |    fps                  | 126        |
# |    iterations           | 38         |
# |    time_elapsed         | 616        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.02332282 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.85      |
# |    explained_variance   | -12.1      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00411   |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0149    |
# |    value_loss           | 0.0728     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.59e+03     |
# |    ep_rew_mean          | 445          |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 39           |
# |    time_elapsed         | 631          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0102730375 |
# |    clip_fraction        | 0.0554       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.00425      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.5          |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00738     |
# |    value_loss           | 25.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.59e+03    |
# |    ep_rew_mean          | 445         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 40          |
# |    time_elapsed         | 647         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006978751 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | -0.000252   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.9         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 44.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.59e+03    |
# |    ep_rew_mean          | 445         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 41          |
# |    time_elapsed         | 663         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008661712 |
# |    clip_fraction        | 0.0611      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | -0.0284     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10          |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00969    |
# |    value_loss           | 15.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.49e+03   |
# |    ep_rew_mean          | 442        |
# | time/                   |            |
# |    fps                  | 126        |
# |    iterations           | 42         |
# |    time_elapsed         | 679        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01426045 |
# |    clip_fraction        | 0.121      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.76      |
# |    explained_variance   | 0.00721    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.3       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0128    |
# |    value_loss           | 23         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.49e+03    |
# |    ep_rew_mean          | 442         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 43          |
# |    time_elapsed         | 695         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005757099 |
# |    clip_fraction        | 0.0311      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.0279      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.9        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0057     |
# |    value_loss           | 41.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.49e+03    |
# |    ep_rew_mean          | 442         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 44          |
# |    time_elapsed         | 710         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012455942 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | -0.115      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.37        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00965    |
# |    value_loss           | 15.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.49e+03    |
# |    ep_rew_mean          | 442         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 45          |
# |    time_elapsed         | 726         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010948219 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.00148     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.6        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 37.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.49e+03    |
# |    ep_rew_mean          | 442         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 46          |
# |    time_elapsed         | 741         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009027947 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | -0.00261    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00758    |
# |    value_loss           | 15.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.49e+03    |
# |    ep_rew_mean          | 442         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 47          |
# |    time_elapsed         | 757         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.019530453 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | -6.78       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0398     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 0.0645      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.01e+03    |
# |    ep_rew_mean          | 461         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 48          |
# |    time_elapsed         | 773         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011700314 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.00223     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.264       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00759    |
# |    value_loss           | 8.1         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.01e+03     |
# |    ep_rew_mean          | 461          |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 49           |
# |    time_elapsed         | 788          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0098146545 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.00147      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0057      |
# |    value_loss           | 9.67         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.01e+03     |
# |    ep_rew_mean          | 461          |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 50           |
# |    time_elapsed         | 804          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0073694736 |
# |    clip_fraction        | 0.0732       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.67        |
# |    explained_variance   | -0.00486     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.6         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00861     |
# |    value_loss           | 29.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.01e+03    |
# |    ep_rew_mean          | 461         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 51          |
# |    time_elapsed         | 820         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.008543698 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | -0.0525     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.4        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00907    |
# |    value_loss           | 30.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.99e+03    |
# |    ep_rew_mean          | 465         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 52          |
# |    time_elapsed         | 836         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.010461124 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.0026      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.4        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00874    |
# |    value_loss           | 29.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.99e+03    |
# |    ep_rew_mean          | 465         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 53          |
# |    time_elapsed         | 851         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.010020992 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.00266     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.9        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 37.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.9e+03     |
# |    ep_rew_mean          | 458         |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 54          |
# |    time_elapsed         | 867         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.014493272 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | -0.0226     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00919    |
# |    value_loss           | 15.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.9e+03      |
# |    ep_rew_mean          | 458          |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 55           |
# |    time_elapsed         | 882          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0121523095 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00185      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.48         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00418     |
# ...
# |    approx_kl            | 0.013966742 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.197      |
# |    explained_variance   | -0.0291     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.164       |
# |    n_updates            | 9590        |
# |    policy_gradient_loss | -0.00468    |
# |    value_loss           | 8           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.24e+03    |
# |    ep_rew_mean          | 462         |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 961         |
# |    time_elapsed         | 18699       |
# |    total_timesteps      | 1968128     |
# | train/                  |             |
# |    approx_kl            | 0.006321214 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.25       |
# |    explained_variance   | 0.0041      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0671      |
# |    n_updates            | 9600        |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 8.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.17e+03    |
# |    ep_rew_mean          | 457         |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 962         |
# |    time_elapsed         | 18714       |
# |    total_timesteps      | 1970176     |
# | train/                  |             |
# |    approx_kl            | 0.004552854 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.265      |
# |    explained_variance   | 0.00515     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.552       |
# |    n_updates            | 9610        |
# |    policy_gradient_loss | -0.00109    |
# |    value_loss           | 8.04        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.17e+03     |
# |    ep_rew_mean          | 457          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 963          |
# |    time_elapsed         | 18728        |
# |    total_timesteps      | 1972224      |
# | train/                  |              |
# |    approx_kl            | 0.0044568274 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.272       |
# |    explained_variance   | 0.00201      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.2         |
# |    n_updates            | 9620         |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 8.16         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.17e+03     |
# |    ep_rew_mean          | 457          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 964          |
# |    time_elapsed         | 18743        |
# |    total_timesteps      | 1974272      |
# | train/                  |              |
# |    approx_kl            | 0.0055018393 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | 0.00174      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.8         |
# |    n_updates            | 9630         |
# |    policy_gradient_loss | -0.00401     |
# |    value_loss           | 43.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.14e+03     |
# |    ep_rew_mean          | 458          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 965          |
# |    time_elapsed         | 18757        |
# |    total_timesteps      | 1976320      |
# | train/                  |              |
# |    approx_kl            | 0.0050421786 |
# |    clip_fraction        | 0.0358       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.254       |
# |    explained_variance   | 0.0098       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.6         |
# |    n_updates            | 9640         |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 22.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.14e+03    |
# |    ep_rew_mean          | 458         |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 966         |
# |    time_elapsed         | 18772       |
# |    total_timesteps      | 1978368     |
# | train/                  |             |
# |    approx_kl            | 0.006216272 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.276      |
# |    explained_variance   | 0.00532     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.37        |
# |    n_updates            | 9650        |
# |    policy_gradient_loss | -0.000894   |
# |    value_loss           | 23.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.04e+03     |
# |    ep_rew_mean          | 452          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 967          |
# |    time_elapsed         | 18787        |
# |    total_timesteps      | 1980416      |
# | train/                  |              |
# |    approx_kl            | 0.0055096163 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.267       |
# |    explained_variance   | 0.00417      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.7         |
# |    n_updates            | 9660         |
# |    policy_gradient_loss | -0.00484     |
# |    value_loss           | 52.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.04e+03     |
# |    ep_rew_mean          | 452          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 968          |
# |    time_elapsed         | 18803        |
# |    total_timesteps      | 1982464      |
# | train/                  |              |
# |    approx_kl            | 0.0026577397 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.24        |
# |    explained_variance   | 0.00867      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.69         |
# |    n_updates            | 9670         |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 15.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.04e+03     |
# |    ep_rew_mean          | 452          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 969          |
# |    time_elapsed         | 18818        |
# |    total_timesteps      | 1984512      |
# | train/                  |              |
# |    approx_kl            | 0.0046328753 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.26        |
# |    explained_variance   | 0.0154       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.2         |
# |    n_updates            | 9680         |
# |    policy_gradient_loss | -0.00487     |
# |    value_loss           | 36.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.97e+03     |
# |    ep_rew_mean          | 451          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 970          |
# |    time_elapsed         | 18833        |
# |    total_timesteps      | 1986560      |
# | train/                  |              |
# |    approx_kl            | 0.0033731959 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.263       |
# |    explained_variance   | 0.0211       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.6          |
# |    n_updates            | 9690         |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 42.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.97e+03    |
# |    ep_rew_mean          | 451         |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 971         |
# |    time_elapsed         | 18848       |
# |    total_timesteps      | 1988608     |
# | train/                  |             |
# |    approx_kl            | 0.004757731 |
# |    clip_fraction        | 0.038       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.258      |
# |    explained_variance   | 0.0042      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.349       |
# |    n_updates            | 9700        |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 15.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.9e+03     |
# |    ep_rew_mean          | 449         |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 972         |
# |    time_elapsed         | 18862       |
# |    total_timesteps      | 1990656     |
# | train/                  |             |
# |    approx_kl            | 0.002558792 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.23       |
# |    explained_variance   | 0.0132      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.1        |
# |    n_updates            | 9710        |
# |    policy_gradient_loss | -0.00222    |
# |    value_loss           | 43.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.9e+03      |
# |    ep_rew_mean          | 449          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 973          |
# |    time_elapsed         | 18877        |
# |    total_timesteps      | 1992704      |
# | train/                  |              |
# |    approx_kl            | 0.0041177524 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.237       |
# |    explained_variance   | 0.0156       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.8         |
# |    n_updates            | 9720         |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 22.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.82e+03     |
# |    ep_rew_mean          | 446          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 974          |
# |    time_elapsed         | 18892        |
# |    total_timesteps      | 1994752      |
# | train/                  |              |
# |    approx_kl            | 0.0029128667 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.256       |
# |    explained_variance   | 0.00406      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.4         |
# |    n_updates            | 9730         |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 45.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.82e+03    |
# |    ep_rew_mean          | 446         |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 975         |
# |    time_elapsed         | 18907       |
# |    total_timesteps      | 1996800     |
# | train/                  |             |
# |    approx_kl            | 0.008735396 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.234      |
# |    explained_variance   | 0.00642     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.3        |
# |    n_updates            | 9740        |
# |    policy_gradient_loss | -0.00173    |
# |    value_loss           | 23.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.78e+03     |
# |    ep_rew_mean          | 443          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 976          |
# |    time_elapsed         | 18922        |
# |    total_timesteps      | 1998848      |
# | train/                  |              |
# |    approx_kl            | 0.0031733993 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.235       |
# |    explained_variance   | 0.0104       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.8         |
# |    n_updates            | 9750         |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 22.7         |
# ------------------------------------------
# Eval num_timesteps=2000000, episode_reward=0.00 +/- 0.00
# Episode length: 400000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 4e+05        |
# |    mean_reward          | 0            |
# | time/                   |              |
# |    total timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0053536575 |
# |    clip_fraction        | 0.0602       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.259       |
# |    explained_variance   | 0.0103       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.23         |
# |    n_updates            | 9760         |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 15.9         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.78e+03 |
# |    ep_rew_mean     | 443      |
# | time/              |          |
# |    fps             | 98       |
# |    iterations      | 977      |
# |    time_elapsed    | 20373    |
# |    total_timesteps | 2000896  |
# ---------------------------------

# %% [markdown]
# #### Visualização do primeiro resultado

# %%
import time

for _ in range(2):
    obs = env_ppo.reset()
    for i in range(1000):
        action, _states = model2.predict(obs, deterministic=True)
        obs, rewards, done, info = env_ppo.step(action)
        time.sleep(0.003)
        env_ppo.render()
        
env_ppo.close()

# %%
env_ppo.close()

# %% [markdown]
# #### Salvamento, carregamento e avaliação do modelo

# %%
# Salva o agente
model2.save("modelos/ppo/recigio_beamrider2M")
# Out:
# c:\xampp\htdocs\posfurb\aprendizadodemaquina\python\.env\lib\site-packages\stable_baselines3\common\save_util.py:276: UserWarning: Path 'modelos\ppo' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
# deleta o agente/modelo
del model2

# %%
# carrega um modelo já treinado
model2 = PPO.load("modelos/ppo/recigio_beamrider2M", env=env_ppo)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
# importando biblioteca de avaliação e avaliando por 10 episodios
from stable_baselines3.common.evaluation import evaluate_policy

mean_reward, std_reward = evaluate_policy(model2, model2.get_env(), n_eval_episodes=10, render=True)
# Out:
# c:\xampp\htdocs\posfurb\aprendizadodemaquina\python\.env\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Não é possível alterar o modo de thread depois de o mesmo estar definido
#   warnings.warn(str(err))

# %%
print(mean_reward)
print(std_reward)
# Out:
# 0.0
# 0.0

# %% [markdown]
# ### DQN

# %%
import gym
import time
from stable_baselines3 import DQN

#carrega o ambiente
env_dqn = gym.make('BeamRiderNoFrameskip-v4')
eval_env_dqn = gym.make('BeamRiderNoFrameskip-v4')

#Para o DQN, para ele conseguir rodar, com a memória que tenho na máquina, tive que setar o batch e buffer_size menor.
#instancia o algoritmo de aprendizagem
model3 = DQN('MlpPolicy', env_dqn, verbose=1,batch_size=128, buffer_size=10000,create_eval_env=True,tensorboard_log="/tmp/stable-baselines/BeamRiderNoFrameskip-v4/custon_dqn")

#treina o algoritmo por 2e5 passos de tempo
model3.learn(total_timesteps=int(2e6),eval_env=eval_env_dqn,eval_freq=200000, n_eval_episodes=1)

# %% [markdown]
# #### Visualização do primeiro resultado

# %%
import time

for _ in range(2):
    obs = env_dqn.reset()
    for i in range(1000):
        action, _states = model3.predict(obs, deterministic=True)
        obs, rewards, done, info = env_dqn.step(action)
        time.sleep(0.003)
        env_dqn.render()
env.close()

# %% [markdown]
# #### Salvamento, carregamento e avaliação do modelo

# %%
# Salva o agente
model3.save("modelos/dqn/recigio_beamrider2M")
# Out:
# c:\xampp\htdocs\posfurb\aprendizadodemaquina\python\.env\lib\site-packages\stable_baselines3\common\save_util.py:276: UserWarning: Path 'modelos\dqn' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
# deleta o agente/modelo
del model3

# %%
# carrega um modelo já treinado
model3 = DQN.load("modelos/dqn/recigio_beamrider_2M", env=env_dqn)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
# importando biblioteca de avaliação e avaliando por 10 episodios
from stable_baselines3.common.evaluation import evaluate_policy

mean_reward, std_reward = evaluate_policy(model3, model3.get_env(), n_eval_episodes=10, render=True)
# Out:
# c:\xampp\htdocs\posfurb\aprendizadodemaquina\python\.env\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Não é possível alterar o modo de thread depois de o mesmo estar definido
#   warnings.warn(str(err))

# %%
print(mean_reward)
print(std_reward)
# Out:
# 44.0
# 0.0

# %% [markdown]
# #### Análise do problema

# %%
# Observei que acontece uma curva no treinamento, onde ele melhora até 800k timesteps, ou um pouco mais,
# depois acredito que acontece algum tipo de overfit ou maximo gradiente, por que ele para de performar e 
# fica parado para o A2C e PPO.
# Devido a isso, farei um novo treinamento limitando a 700k steps.

# %% [markdown]
# #### Gráficos do tensor Flow

# %% [markdown]
# ![mean_reward](graficos/2M_1.png)

# %% [markdown]
# ![mean_ep_length](graficos/2M_2.png)

# %% [markdown]
# ### Novos treinamentos

# %%
import gym
import time
from stable_baselines3 import A2C,PPO,DQN
from stable_baselines3.common.sb2_compat.rmsprop_tf_like import RMSpropTFLike

#carrega o ambiente
env = gym.make('BeamRiderNoFrameskip-v4')
eval_env = gym.make('BeamRiderNoFrameskip-v4')

#instancia o algoritmo de aprendizagem
model = A2C('MlpPolicy', env, verbose=1,create_eval_env=True,ent_coef=0.01,vf_coef=0.25,policy_kwargs=dict(optimizer_class=RMSpropTFLike, optimizer_kwargs=dict(eps=1e-5)),tensorboard_log="/tmp/stable-baselines/BeamRiderNoFrameskip-v4/custon2_a2c")

#treina o algoritmo
model.learn(total_timesteps=700000,eval_env=eval_env,eval_freq=175000, n_eval_episodes=1)

model.save("modelos/a2c/recigio_beamrider_700k")
del model
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to /tmp/stable-baselines/BeamRiderNoFrameskip-v4/custon2_a2c\A2C_1
# -------------------------------------
# | time/                 |           |
# |    fps                | 116       |
# |    iterations         | 100       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -4.97e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 0.0732    |
# |    value_loss         | 0.0445    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 143      |
# |    iterations         | 200      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -56.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.215   |
# |    value_loss         | 0.0107   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 157      |
# |    iterations         | 300      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -47      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0498  |
# |    value_loss         | 0.000923 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 400      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -46.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.144   |
# |    value_loss         | 0.00458  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 165      |
# |    iterations         | 500      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -13.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.046    |
# |    value_loss         | 0.000764 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 169      |
# |    iterations         | 600      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -25.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.116    |
# |    value_loss         | 0.00359  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 170      |
# |    iterations         | 700      |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.0468   |
# |    value_loss         | 0.000553 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 171      |
# |    iterations         | 800      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -56.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.461    |
# |    value_loss         | 0.0562   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 173      |
# |    iterations         | 900      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -4.27    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0978  |
# |    value_loss         | 0.00227  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 175      |
# |    iterations         | 1000     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0156  |
# |    value_loss         | 6.15e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 175       |
# |    iterations         | 1100      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -3.24e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -0.0191   |
# |    value_loss         | 0.000107  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 177       |
# |    iterations         | 1200      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -6.67e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 0.012     |
# |    value_loss         | 3.98e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 6.09e+03  |
# |    ep_rew_mean        | 528       |
# | time/                 |           |
# |    fps                | 178       |
# |    iterations         | 1300      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -2.36e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -0.0273   |
# |    value_loss         | 0.000192  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.09e+03 |
# |    ep_rew_mean        | 528      |
# | time/                 |          |
# |    fps                | 178      |
# |    iterations         | 1400     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -17.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.0257   |
# |    value_loss         | 0.00016  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.09e+03 |
# |    ep_rew_mean        | 528      |
# | time/                 |          |
# |    fps                | 178      |
# |    iterations         | 1500     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -2.84    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.00103  |
# |    value_loss         | 3.25e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.09e+03 |
# |    ep_rew_mean        | 528      |
# | time/                 |          |
# |    fps                | 177      |
# |    iterations         | 1600     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -74.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.0153  |
# |    value_loss         | 5.67e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.09e+03 |
# |    ep_rew_mean        | 528      |
# | time/                 |          |
# |    fps                | 177      |
# |    iterations         | 1700     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -14.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.00324  |
# |    value_loss         | 5.1e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.09e+03 |
# |    ep_rew_mean        | 528      |
# | time/                 |          |
# |    fps                | 177      |
# |    iterations         | 1800     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -162     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.00489 |
# |    value_loss         | 1.49e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.09e+03 |
# |    ep_rew_mean        | 528      |
# | time/                 |          |
# |    fps                | 177      |
# |    iterations         | 1900     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -38.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.00195 |
# |    value_loss         | 2.94e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 6.09e+03  |
# |    ep_rew_mean        | 528       |
# | time/                 |           |
# |    fps                | 178       |
# |    iterations         | 2000      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -3.72e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.00245   |
# |    value_loss         | 1.1e-05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.09e+03 |
# |    ep_rew_mean        | 528      |
# | time/                 |          |
# |    fps                | 178      |
# |    iterations         | 2100     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -587     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.00745 |
# |    value_loss         | 1.34e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.46e+03  |
# |    ep_rew_mean        | 374       |
# | time/                 |           |
# |    fps                | 179       |
# |    iterations         | 2200      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -1.26e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | 0.0178    |
# |    value_loss         | 7.94e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.46e+03 |
# |    ep_rew_mean        | 374      |
# | time/                 |          |
# |    fps                | 179      |
# |    iterations         | 2300     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -12.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.0132  |
# |    value_loss         | 3.69e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.46e+03 |
# |    ep_rew_mean        | 374      |
# | time/                 |          |
# |    fps                | 180      |
# |    iterations         | 2400     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -101     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.00592  |
# |    value_loss         | 1.29e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.46e+03 |
# |    ep_rew_mean        | 374      |
# | time/                 |          |
# |    fps                | 180      |
# |    iterations         | 2500     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -1.4     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.0289   |
# |    value_loss         | 0.000179 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.46e+03 |
# |    ep_rew_mean        | 374      |
# | time/                 |          |
# |    fps                | 180      |
# |    iterations         | 2600     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | -284     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.0103  |
# |    value_loss         | 2.21e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.46e+03 |
# |    ep_rew_mean        | 374      |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 2700     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -427     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.00509  |
# |    value_loss         | 8.5e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.46e+03 |
# |    ep_rew_mean        | 374      |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 2800     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -45.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.00635 |
# |    value_loss         | 1.06e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.46e+03 |
# |    ep_rew_mean        | 374      |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 2900     |
# |    time_elapsed       | 79       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -21.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.00793  |
# |    value_loss         | 1.7e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.46e+03 |
# |    ep_rew_mean        | 374      |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 3000     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -11.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00127  |
# |    value_loss         | 2.98e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.46e+03 |
# |    ep_rew_mean        | 374      |
# | time/                 |          |
# |    fps                | 182      |
# |    iterations         | 3100     |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 7.55e-05 |
# |    value_loss         | 1.45e-09 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.17e+03 |
# |    ep_rew_mean        | 337      |
# | time/                 |          |
# |    fps                | 182      |
# |    iterations         | 3200     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -9.99    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.00122  |
# |    value_loss         | 8.24e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.17e+03 |
# |    ep_rew_mean        | 337      |
# | time/                 |          |
# |    fps                | 182      |
# |    iterations         | 3300     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -16.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.00671  |
# |    value_loss         | 1.78e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.17e+03 |
# |    ep_rew_mean        | 337      |
# | time/                 |          |
# |    fps                | 182      |
# |    iterations         | 3400     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -181     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.00482  |
# |    value_loss         | 1.47e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.17e+03 |
# |    ep_rew_mean        | 337      |
# | time/                 |          |
# |    fps                | 182      |
# |    iterations         | 3500     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -116     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.00212  |
# |    value_loss         | 4.24e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.17e+03 |
# |    ep_rew_mean        | 337      |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 3600     |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -0.133   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.00953 |
# |    value_loss         | 2.88e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.17e+03 |
# |    ep_rew_mean        | 337      |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 3700     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | -949     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.0353  |
# |    value_loss         | 0.000354 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.17e+03 |
# |    ep_rew_mean        | 337      |
# | time/                 |          |
# |    fps                | 180      |
# |    iterations         | 3800     |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | -259     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.0142  |
# |    value_loss         | 4.48e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.17e+03 |
# |    ep_rew_mean        | 337      |
# | time/                 |          |
# |    fps                | 180      |
# |    iterations         | 3900     |
# |    time_elapsed       | 107      |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -526     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.00911  |
# |    value_loss         | 2.93e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.17e+03 |
# |    ep_rew_mean        | 337      |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 4000     |
# |    time_elapsed       | 110      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -2.54    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.00697 |
# |    value_loss         | 1.04e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.17e+03  |
# |    ep_rew_mean        | 337       |
# | time/                 |           |
# |    fps                | 181       |
# |    iterations         | 4100      |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -2.47e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | 0.0073    |
# |    value_loss         | 1.19e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.22e+03  |
# |    ep_rew_mean        | 330       |
# | time/                 |           |
# |    fps                | 181       |
# |    iterations         | 4200      |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -1.01e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -0.00253  |
# |    value_loss         | 3.53e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.22e+03  |
# |    ep_rew_mean        | 330       |
# | time/                 |           |
# |    fps                | 181       |
# |    iterations         | 4300      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -0.211    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -0.000229 |
# |    value_loss         | 1.13e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.22e+03 |
# |    ep_rew_mean        | 330      |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 4400     |
# |    time_elapsed       | 121      |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -1.93    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.00669 |
# |    value_loss         | 1.28e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.22e+03  |
# |    ep_rew_mean        | 330       |
# | time/                 |           |
# |    fps                | 182       |
# |    iterations         | 4500      |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -1.12e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -0.00641  |
# |    value_loss         | 4.27e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.22e+03 |
# |    ep_rew_mean        | 330      |
# | time/                 |          |
# |    fps                | 182      |
# |    iterations         | 4600     |
# |    time_elapsed       | 126      |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -906     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.017   |
# |    value_loss         | 7.32e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.22e+03 |
# |    ep_rew_mean        | 330      |
# | time/                 |          |
# |    fps                | 182      |
# |    iterations         | 4700     |
# |    time_elapsed       | 128      |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -58      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.00871  |
# |    value_loss         | 2.55e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.22e+03 |
# |    ep_rew_mean        | 330      |
# | time/                 |          |
# |    fps                | 182      |
# |    iterations         | 4800     |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -585     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.0027  |
# |    value_loss         | 7.56e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.22e+03 |
# |    ep_rew_mean        | 330      |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 4900     |
# |    time_elapsed       | 133      |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -54.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.00289  |
# |    value_loss         | 7.47e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.22e+03  |
# |    ep_rew_mean        | 330       |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 5000      |
# |    time_elapsed       | 136       |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -14.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -0.000941 |
# |    value_loss         | 1.73e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.22e+03  |
# |    ep_rew_mean        | 330       |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 5100      |
# |    time_elapsed       | 139       |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -212      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -0.000964 |
# |    value_loss         | 6.88e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.22e+03 |
# |    ep_rew_mean        | 330      |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 5200     |
# |    time_elapsed       | 141      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -0.544   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.00057  |
# |    value_loss         | 1.27e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.22e+03  |
# |    ep_rew_mean        | 330       |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 5300      |
# |    time_elapsed       | 144       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -3.28e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | 0.0013    |
# |    value_loss         | 5.49e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.22e+03  |
# |    ep_rew_mean        | 330       |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 5400      |
# |    time_elapsed       | 147       |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -0.994    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -0.000744 |
# |    value_loss         | 1.49e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.22e+03  |
# |    ep_rew_mean        | 330       |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 5500      |
# |    time_elapsed       | 149       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -2.58e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | 0.00122   |
# |    value_loss         | 1.87e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.57e+03 |
# |    ep_rew_mean        | 343      |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 5600     |
# |    time_elapsed       | 152      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -83.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.00223 |
# |    value_loss         | 1.64e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.57e+03 |
# |    ep_rew_mean        | 343      |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 5700     |
# |    time_elapsed       | 155      |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -3.26    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.00367  |
# |    value_loss         | 8.66e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.57e+03 |
# |    ep_rew_mean        | 343      |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 5800     |
# |    time_elapsed       | 157      |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -63.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.0148  |
# |    value_loss         | 5.66e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.57e+03  |
# |    ep_rew_mean        | 343       |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 5900      |
# |    time_elapsed       | 160       |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -1.56e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | 0.00977   |
# |    value_loss         | 2.6e-05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.57e+03 |
# |    ep_rew_mean        | 343      |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 6000     |
# |    time_elapsed       | 163      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | -3.28    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.00818 |
# |    value_loss         | 3.79e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.57e+03 |
# |    ep_rew_mean        | 343      |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 6100     |
# |    time_elapsed       | 165      |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -34.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 3.71e-05 |
# |    value_loss         | 2.37e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.57e+03 |
# |    ep_rew_mean        | 343      |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 6200     |
# |    time_elapsed       | 168      |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -3.37    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.0224  |
# |    value_loss         | 0.000146 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.57e+03 |
# |    ep_rew_mean        | 343      |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 6300     |
# |    time_elapsed       | 171      |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -10.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.00204  |
# |    value_loss         | 6.17e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.57e+03  |
# |    ep_rew_mean        | 343       |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 6400      |
# |    time_elapsed       | 174       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -2.19     |
# |    explained_variance | -5.68e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 0.00489   |
# |    value_loss         | 9.99e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.57e+03 |
# |    ep_rew_mean        | 343      |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 6500     |
# |    time_elapsed       | 176      |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -1.3     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.013   |
# |    value_loss         | 4.22e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.57e+03 |
# |    ep_rew_mean        | 343      |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 6600     |
# |    time_elapsed       | 179      |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | -21      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.00652  |
# |    value_loss         | 1.12e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.51e+03  |
# |    ep_rew_mean        | 367       |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 6700      |
# |    time_elapsed       | 182       |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -3.13e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -0.000702 |
# |    value_loss         | 1.82e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.51e+03 |
# |    ep_rew_mean        | 367      |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 6800     |
# |    time_elapsed       | 184      |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | 0.693    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.00369  |
# |    value_loss         | 6.34e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.51e+03 |
# |    ep_rew_mean        | 367      |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 6900     |
# |    time_elapsed       | 187      |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -87.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.00368  |
# |    value_loss         | 3.1e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.51e+03 |
# |    ep_rew_mean        | 367      |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 7000     |
# |    time_elapsed       | 190      |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -15.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.00219  |
# |    value_loss         | 1.86e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.51e+03 |
# |    ep_rew_mean        | 367      |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 7100     |
# |    time_elapsed       | 192      |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -0.649   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.0216  |
# |    value_loss         | 0.000121 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.51e+03 |
# |    ep_rew_mean        | 367      |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 7200     |
# |    time_elapsed       | 195      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -4.08    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 0.031    |
# |    value_loss         | 0.0002   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.51e+03 |
# |    ep_rew_mean        | 367      |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 7300     |
# |    time_elapsed       | 198      |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -8.06    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 0.00242  |
# |    value_loss         | 1.51e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.51e+03  |
# |    ep_rew_mean        | 367       |
# | time/                 |           |
# |    fps                | 184       |
# |    iterations         | 7400      |
# |    time_elapsed       | 201       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -2.19     |
# |    explained_variance | -1.31e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -0.00824  |
# |    value_loss         | 2.67e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.51e+03 |
# |    ep_rew_mean        | 367      |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 7500     |
# |    time_elapsed       | 203      |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | 0.902    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.0172  |
# |    value_loss         | 6.06e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.51e+03 |
# |    ep_rew_mean        | 367      |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 7600     |
# |    time_elapsed       | 206      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -8.79    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.0164   |
# |    value_loss         | 5.95e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.51e+03  |
# |    ep_rew_mean        | 367       |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 7700      |
# |    time_elapsed       | 209       |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -2.19     |
# |    explained_variance | -27.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -0.000347 |
# |    value_loss         | 3e-06     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.51e+03 |
# |    ep_rew_mean        | 367      |
# | time/                 |          |
# |    fps                | 183      |
# ...
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 137700   |
# |    time_elapsed       | 3607     |
# |    total_timesteps    | 688500   |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | 0.85     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 137699   |
# |    policy_loss        | -0.00265 |
# |    value_loss         | 1.76e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.24e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 137800   |
# |    time_elapsed       | 3610     |
# |    total_timesteps    | 689000   |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -23.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 137799   |
# |    policy_loss        | -0.00041 |
# |    value_loss         | 3.87e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.24e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 137900   |
# |    time_elapsed       | 3612     |
# |    total_timesteps    | 689500   |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | 0.475    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 137899   |
# |    policy_loss        | -0.00706 |
# |    value_loss         | 1.23e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.24e+03  |
# |    ep_rew_mean        | 348       |
# | time/                 |           |
# |    fps                | 190       |
# |    iterations         | 138000    |
# |    time_elapsed       | 3615      |
# |    total_timesteps    | 690000    |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -57       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 137999    |
# |    policy_loss        | -0.000657 |
# |    value_loss         | 7.83e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.24e+03  |
# |    ep_rew_mean        | 348       |
# | time/                 |           |
# |    fps                | 190       |
# |    iterations         | 138100    |
# |    time_elapsed       | 3618      |
# |    total_timesteps    | 690500    |
# | train/                |           |
# |    entropy_loss       | -2.2      |
# |    explained_variance | -1.46e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 138099    |
# |    policy_loss        | 0.000412  |
# |    value_loss         | 4.96e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.24e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 138200   |
# |    time_elapsed       | 3620     |
# |    total_timesteps    | 691000   |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | -0.176   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 138199   |
# |    policy_loss        | -0.0137  |
# |    value_loss         | 4.63e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.24e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 138300   |
# |    time_elapsed       | 3623     |
# |    total_timesteps    | 691500   |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | -9.58    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 138299   |
# |    policy_loss        | 0.000407 |
# |    value_loss         | 1.4e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.24e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 138400   |
# |    time_elapsed       | 3625     |
# |    total_timesteps    | 692000   |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | -2.79    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 138399   |
# |    policy_loss        | 0.00175  |
# |    value_loss         | 1.35e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.24e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 138500   |
# |    time_elapsed       | 3628     |
# |    total_timesteps    | 692500   |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | -3.52    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 138499   |
# |    policy_loss        | -0.0102  |
# |    value_loss         | 3.01e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.26e+03  |
# |    ep_rew_mean        | 348       |
# | time/                 |           |
# |    fps                | 190       |
# |    iterations         | 138600    |
# |    time_elapsed       | 3631      |
# |    total_timesteps    | 693000    |
# | train/                |           |
# |    entropy_loss       | -2.19     |
# |    explained_variance | -2.82e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 138599    |
# |    policy_loss        | -0.003    |
# |    value_loss         | 4.85e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.26e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 138700   |
# |    time_elapsed       | 3633     |
# |    total_timesteps    | 693500   |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -0.085   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 138699   |
# |    policy_loss        | -0.0059  |
# |    value_loss         | 7.37e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.26e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 138800   |
# |    time_elapsed       | 3636     |
# |    total_timesteps    | 694000   |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | 0.359    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 138799   |
# |    policy_loss        | -0.00422 |
# |    value_loss         | 5.47e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.26e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 138900   |
# |    time_elapsed       | 3638     |
# |    total_timesteps    | 694500   |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | -71.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 138899   |
# |    policy_loss        | 0.00335  |
# |    value_loss         | 3.53e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.26e+03  |
# |    ep_rew_mean        | 348       |
# | time/                 |           |
# |    fps                | 190       |
# |    iterations         | 139000    |
# |    time_elapsed       | 3641      |
# |    total_timesteps    | 695000    |
# | train/                |           |
# |    entropy_loss       | -2.19     |
# |    explained_variance | -1.38e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 138999    |
# |    policy_loss        | -0.00456  |
# |    value_loss         | 6.36e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.26e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 139100   |
# |    time_elapsed       | 3643     |
# |    total_timesteps    | 695500   |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -566     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 139099   |
# |    policy_loss        | -0.00469 |
# |    value_loss         | 5.2e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.26e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 139200   |
# |    time_elapsed       | 3646     |
# |    total_timesteps    | 696000   |
# | train/                |          |
# |    entropy_loss       | -2.19    |
# |    explained_variance | -1.8e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 139199   |
# |    policy_loss        | 55.7     |
# |    value_loss         | 1.14e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.26e+03  |
# |    ep_rew_mean        | 348       |
# | time/                 |           |
# |    fps                | 190       |
# |    iterations         | 139300    |
# |    time_elapsed       | 3649      |
# |    total_timesteps    | 696500    |
# | train/                |           |
# |    entropy_loss       | -2.19     |
# |    explained_variance | -1.76e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 139299    |
# |    policy_loss        | 0.0209    |
# |    value_loss         | 0.000144  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.26e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 139400   |
# |    time_elapsed       | 3651     |
# |    total_timesteps    | 697000   |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -0.516   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 139399   |
# |    policy_loss        | -0.00829 |
# |    value_loss         | 1.78e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.26e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 139500   |
# |    time_elapsed       | 3654     |
# |    total_timesteps    | 697500   |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -89.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 139499   |
# |    policy_loss        | 0.00386  |
# |    value_loss         | 5.08e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 5.26e+03  |
# |    ep_rew_mean        | 348       |
# | time/                 |           |
# |    fps                | 190       |
# |    iterations         | 139600    |
# |    time_elapsed       | 3656      |
# |    total_timesteps    | 698000    |
# | train/                |           |
# |    entropy_loss       | -2.19     |
# |    explained_variance | -1.77e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 139599    |
# |    policy_loss        | -0.00261  |
# |    value_loss         | 3.2e-06   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.26e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 139700   |
# |    time_elapsed       | 3659     |
# |    total_timesteps    | 698500   |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -47.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 139699   |
# |    policy_loss        | 0.00242  |
# |    value_loss         | 1.58e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.26e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 139800   |
# |    time_elapsed       | 3661     |
# |    total_timesteps    | 699000   |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -24.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 139799   |
# |    policy_loss        | 0.000985 |
# |    value_loss         | 2.1e-07  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.26e+03 |
# |    ep_rew_mean        | 348      |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 139900   |
# |    time_elapsed       | 3664     |
# |    total_timesteps    | 699500   |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | -0.161   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 139899   |
# |    policy_loss        | -0.00457 |
# |    value_loss         | 4.91e-06 |
# ------------------------------------
# Eval num_timesteps=700000, episode_reward=1188.00 +/- 0.00
# Episode length: 15097.00 +/- 0.00
# -------------------------------------
# | eval/                 |           |
# |    mean_ep_length     | 1.51e+04  |
# |    mean_reward        | 1.19e+03  |
# | time/                 |           |
# |    total timesteps    | 700000    |
# | train/                |           |
# |    entropy_loss       | -2.19     |
# |    explained_variance | 0.662     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 139999    |
# |    policy_loss        | -0.000919 |
# |    value_loss         | 5.28e-07  |
# -------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.26e+03 |
# |    ep_rew_mean     | 348      |
# | time/              |          |
# |    fps             | 189      |
# |    iterations      | 140000   |
# |    time_elapsed    | 3698     |
# |    total_timesteps | 700000   |
# ---------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-afc8c08f3801> in <module>
#      21
#      22 #instancia o algoritmo de aprendizagem
# ---> 23 model = PPO('MlpPolicy', env, verbose=1, vf_coef= 0.5, ent_coef=0.01, create_eval_env=True, batch_size=256,cliprange=0.1,tensorboard_log="/tmp/stable-baselines/BeamRiderNoFrameskip-v4/custon2_ppo")
#      24
#      25 #treina o algoritmo por 2e5 passos de tempo
#
# TypeError: __init__() got an unexpected keyword argument 'cliprange'

# %%
env.reset()
eval_env.reset()

#instancia o algoritmo de aprendizagem
model = PPO('MlpPolicy', env, verbose=1, vf_coef= 0.5, ent_coef=0.01, create_eval_env=True, batch_size=256,clip_range=0.1,tensorboard_log="/tmp/stable-baselines/BeamRiderNoFrameskip-v4/custon2_ppo")

#treina o algoritmo
model.learn(total_timesteps=700000,eval_env=eval_env,eval_freq=175000, n_eval_episodes=1)

model.save("modelos/ppo/recigio_beamrider_700k")
del model
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to /tmp/stable-baselines/BeamRiderNoFrameskip-v4/custon2_ppo\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 403  |
# |    iterations      | 1    |
# |    time_elapsed    | 5    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 2           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.002402385 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | -0.00234    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.06        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00856    |
# |    value_loss           | 21.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 193          |
# |    iterations           | 3            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0033570235 |
# |    clip_fraction        | 0.153        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | -0.00794     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.3         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 13.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 182          |
# |    iterations           | 4            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0036117812 |
# |    clip_fraction        | 0.18         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | -0.0135      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.82         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0081      |
# |    value_loss           | 6.3          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.93e+03     |
# |    ep_rew_mean          | 396          |
# | time/                   |              |
# |    fps                  | 176          |
# |    iterations           | 5            |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0045192083 |
# |    clip_fraction        | 0.24         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | -0.665       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0455      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.019       |
# |    value_loss           | 0.0334       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.93e+03    |
# |    ep_rew_mean          | 396         |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 6           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.002165405 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | -0.000903   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.3        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00797    |
# |    value_loss           | 41.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.93e+03     |
# |    ep_rew_mean          | 396          |
# | time/                   |              |
# |    fps                  | 170          |
# |    iterations           | 7            |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0021102633 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.74         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0098      |
# |    value_loss           | 13           |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.49e+03   |
# |    ep_rew_mean          | 418        |
# | time/                   |            |
# |    fps                  | 169        |
# |    iterations           | 8          |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00190853 |
# |    clip_fraction        | 0.0661     |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.18      |
# |    explained_variance   | 0.0767     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.2       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00917   |
# |    value_loss           | 20.5       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.49e+03     |
# |    ep_rew_mean          | 418          |
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 9            |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0016310599 |
# |    clip_fraction        | 0.0476       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.18        |
# |    explained_variance   | 0.0668       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.9         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00964     |
# |    value_loss           | 33.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.49e+03     |
# |    ep_rew_mean          | 418          |
# | time/                   |              |
# |    fps                  | 166          |
# |    iterations           | 10           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0048260964 |
# |    clip_fraction        | 0.192        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.18        |
# |    explained_variance   | -0.436       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00765      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0172      |
# |    value_loss           | 0.292        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.03e+03    |
# |    ep_rew_mean          | 411         |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 11          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.002131322 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | -0.0422     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00927    |
# |    value_loss           | 26.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.03e+03     |
# |    ep_rew_mean          | 411          |
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 12           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0018589884 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.18        |
# |    explained_variance   | 0.0319       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22           |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 38.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.32e+03     |
# |    ep_rew_mean          | 385          |
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 13           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0023641365 |
# |    clip_fraction        | 0.0661       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.18        |
# |    explained_variance   | -0.149       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.04         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0111      |
# |    value_loss           | 13.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.32e+03     |
# |    ep_rew_mean          | 385          |
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 14           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0019832891 |
# |    clip_fraction        | 0.0659       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.18        |
# |    explained_variance   | 0.052        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.9          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0111      |
# |    value_loss           | 13.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.32e+03     |
# |    ep_rew_mean          | 385          |
# | time/                   |              |
# |    fps                  | 163          |
# |    iterations           | 15           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0026551187 |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.18        |
# |    explained_variance   | -0.0917      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.24         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 14.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.42e+03     |
# |    ep_rew_mean          | 387          |
# | time/                   |              |
# |    fps                  | 163          |
# |    iterations           | 16           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0019146933 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | 0.00174      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.2         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.01        |
# |    value_loss           | 33.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.42e+03     |
# |    ep_rew_mean          | 387          |
# | time/                   |              |
# |    fps                  | 163          |
# |    iterations           | 17           |
# |    time_elapsed         | 213          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0029662526 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | -0.0823      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.47         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0119      |
# |    value_loss           | 7.59         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.42e+03     |
# |    ep_rew_mean          | 387          |
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 18           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0020630783 |
# |    clip_fraction        | 0.0505       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | -0.0259      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.5         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 61.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.42e+03     |
# |    ep_rew_mean          | 387          |
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 19           |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0024833202 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | -0.174       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.15         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0121      |
# |    value_loss           | 14.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.42e+03     |
# |    ep_rew_mean          | 387          |
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 20           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0028500766 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | -0.0119      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.82         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0131      |
# |    value_loss           | 21.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.42e+03     |
# |    ep_rew_mean          | 387          |
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 21           |
# |    time_elapsed         | 266          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0061480897 |
# |    clip_fraction        | 0.227        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | -5.37        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0396       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0114      |
# |    value_loss           | 0.355        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.47e+03    |
# |    ep_rew_mean          | 433         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 22          |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005855142 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | -3.49       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0349     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.116       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.47e+03    |
# |    ep_rew_mean          | 433         |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 23          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004007526 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.000996    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.25        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00908    |
# |    value_loss           | 7.82        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.47e+03   |
# |    ep_rew_mean          | 433        |
# | time/                   |            |
# |    fps                  | 160        |
# |    iterations           | 24         |
# |    time_elapsed         | 305        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00343685 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.16      |
# |    explained_variance   | -0.0179    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.77       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00866   |
# |    value_loss           | 19.1       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.15e+03     |
# |    ep_rew_mean          | 415          |
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 25           |
# |    time_elapsed         | 318          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0028394733 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | -0.0125      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.4         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 30.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.15e+03     |
# |    ep_rew_mean          | 415          |
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 26           |
# |    time_elapsed         | 331          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0030427228 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | 0.0086       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.3         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 22.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.15e+03   |
# |    ep_rew_mean          | 415        |
# | time/                   |            |
# |    fps                  | 160        |
# |    iterations           | 27         |
# |    time_elapsed         | 344        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00408935 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.16      |
# |    explained_variance   | -0.0881    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.72       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0114    |
# |    value_loss           | 15.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.97e+03    |
# |    ep_rew_mean          | 424         |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 28          |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.002211832 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.00948     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 42.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.97e+03     |
# |    ep_rew_mean          | 424          |
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 29           |
# |    time_elapsed         | 370          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0022937371 |
# |    clip_fraction        | 0.0821       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | 0.0446       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19           |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 32.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.97e+03    |
# |    ep_rew_mean          | 424         |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 30          |
# |    time_elapsed         | 383         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.003165502 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.0081      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 19.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.85e+03     |
# |    ep_rew_mean          | 435          |
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 31           |
# |    time_elapsed         | 396          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0025642086 |
# |    clip_fraction        | 0.075        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | -0.111       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.7         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 35           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.85e+03     |
# |    ep_rew_mean          | 435          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 32           |
# |    time_elapsed         | 409          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0022869892 |
# |    clip_fraction        | 0.0732       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | 0.0192       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.6         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0111      |
# |    value_loss           | 40.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.64e+03     |
# |    ep_rew_mean          | 436          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 33           |
# |    time_elapsed         | 422          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0019920182 |
# |    clip_fraction        | 0.0659       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | 0.0451       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.3         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0116      |
# |    value_loss           | 27           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.64e+03     |
# |    ep_rew_mean          | 436          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 34           |
# |    time_elapsed         | 435          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0025667164 |
# |    clip_fraction        | 0.0846       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 0.15         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.56         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 18.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.44e+03    |
# |    ep_rew_mean          | 424         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 35          |
# |    time_elapsed         | 448         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.004603373 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | -0.761      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.165       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 0.979       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.44e+03     |
# |    ep_rew_mean          | 424          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 36           |
# |    time_elapsed         | 461          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0033448273 |
# |    clip_fraction        | 0.189        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | -0.00794     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.1         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.012       |
# |    value_loss           | 46.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.44e+03    |
# |    ep_rew_mean          | 424         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 37          |
# |    time_elapsed         | 474         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004657612 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | -0.195      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.812       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 8.43        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.34e+03     |
# |    ep_rew_mean          | 407          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 38           |
# |    time_elapsed         | 487          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0041699354 |
# |    clip_fraction        | 0.195        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.13        |
# |    explained_variance   | 0.00486      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.33         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0119      |
# |    value_loss           | 15.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.34e+03     |
# |    ep_rew_mean          | 407          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 39           |
# |    time_elapsed         | 500          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0030041395 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.13        |
# |    explained_variance   | 0.0164       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.7         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0141      |
# |    value_loss           | 29.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.34e+03     |
# |    ep_rew_mean          | 407          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 40           |
# |    time_elapsed         | 513          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0031629915 |
# |    clip_fraction        | 0.145        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.13        |
# |    explained_variance   | -0.000499    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15           |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0133      |
# |    value_loss           | 28.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.34e+03   |
# |    ep_rew_mean          | 423        |
# | time/                   |            |
# |    fps                  | 159        |
# |    iterations           | 41         |
# |    time_elapsed         | 526        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.00283902 |
# |    clip_fraction        | 0.122      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.13      |
# |    explained_variance   | 0.024      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.4       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0118    |
# |    value_loss           | 31.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.34e+03    |
# |    ep_rew_mean          | 423         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 42          |
# |    time_elapsed         | 540         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004617631 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | -0.149      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.72        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 8.37        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.28e+03     |
# |    ep_rew_mean          | 396          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 43           |
# |    time_elapsed         | 552          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0072590066 |
# |    clip_fraction        | 0.217        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | -0.151       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.17         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00901     |
# |    value_loss           | 7.64         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.28e+03     |
# |    ep_rew_mean          | 396          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 44           |
# |    time_elapsed         | 565          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0067481156 |
# |    clip_fraction        | 0.248        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | -0.203       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0518       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 0.196        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.28e+03     |
# |    ep_rew_mean          | 396          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 45           |
# |    time_elapsed         | 579          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0040158113 |
# |    clip_fraction        | 0.177        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.11        |
# |    explained_variance   | -8.31e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.4         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0111      |
# |    value_loss           | 36.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.28e+03     |
# |    ep_rew_mean          | 396          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 46           |
# |    time_elapsed         | 592          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0050148303 |
# |    clip_fraction        | 0.227        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.11        |
# |    explained_variance   | -0.0382      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.62         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0118      |
# |    value_loss           | 15.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.3e+03    |
# |    ep_rew_mean          | 396        |
# | time/                   |            |
# |    fps                  | 159        |
# |    iterations           | 47         |
# |    time_elapsed         | 605        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.00472337 |
# |    clip_fraction        | 0.241      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.1       |
# |    explained_variance   | -0.000144  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.79       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.00891   |
# |    value_loss           | 15.5       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.3e+03      |
# |    ep_rew_mean          | 396          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 48           |
# |    time_elapsed         | 618          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0034002136 |
# |    clip_fraction        | 0.155        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.1         |
# |    explained_variance   | -0.00128     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.4         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0119      |
# |    value_loss           | 47.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.3e+03      |
# |    ep_rew_mean          | 396          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 49           |
# |    time_elapsed         | 631          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0043812064 |
# |    clip_fraction        | 0.183        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | -0.0696      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.2          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 15.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.34e+03     |
# |    ep_rew_mean          | 407          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 50           |
# |    time_elapsed         | 644          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0039727734 |
# |    clip_fraction        | 0.202        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | -0.0412      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.8         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0143      |
# |    value_loss           | 30.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.34e+03     |
# |    ep_rew_mean          | 407          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 51           |
# |    time_elapsed         | 657          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0041959477 |
# |    clip_fraction        | 0.221        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | 0.00651      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.1         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0113      |
# |    value_loss           | 29.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.34e+03     |
# |    ep_rew_mean          | 407          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 52           |
# |    time_elapsed         | 670          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0058196615 |
# |    clip_fraction        | 0.216        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | -0.0362      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.93         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 8.45         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.33e+03    |
# |    ep_rew_mean          | 401         |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 53          |
# |    time_elapsed         | 683         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.004101943 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | 0.023       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.28        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 14.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.33e+03     |
# |    ep_rew_mean          | 401          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 54           |
# |    time_elapsed         | 696          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0057900753 |
# |    clip_fraction        | 0.288        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | 0.0611       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.52         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0136      |
# |    value_loss           | 21.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.33e+03     |
# |    ep_rew_mean          | 401          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 55           |
# |    time_elapsed         | 709          |
# |    total_timesteps      | 112640       |
# ...
# | train/                  |              |
# |    approx_kl            | 0.0043741195 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00351      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.6         |
# |    n_updates            | 3240         |
# |    policy_gradient_loss | -0.00507     |
# |    value_loss           | 44.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.01e+03     |
# |    ep_rew_mean          | 459          |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 326          |
# |    time_elapsed         | 4297         |
# |    total_timesteps      | 667648       |
# | train/                  |              |
# |    approx_kl            | 0.0041617863 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00576      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.3         |
# |    n_updates            | 3250         |
# |    policy_gradient_loss | -0.00402     |
# |    value_loss           | 49.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.01e+03     |
# |    ep_rew_mean          | 459          |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 327          |
# |    time_elapsed         | 4310         |
# |    total_timesteps      | 669696       |
# | train/                  |              |
# |    approx_kl            | 0.0043907375 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00784     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.69         |
# |    n_updates            | 3260         |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 8.35         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.01e+03    |
# |    ep_rew_mean          | 459         |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 328         |
# |    time_elapsed         | 4323        |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.005020452 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00549     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.4        |
# |    n_updates            | 3270        |
# |    policy_gradient_loss | -0.00376    |
# |    value_loss           | 36.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.03e+03     |
# |    ep_rew_mean          | 461          |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 329          |
# |    time_elapsed         | 4336         |
# |    total_timesteps      | 673792       |
# | train/                  |              |
# |    approx_kl            | 0.0068171937 |
# |    clip_fraction        | 0.163        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00716      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.3         |
# |    n_updates            | 3280         |
# |    policy_gradient_loss | -0.00627     |
# |    value_loss           | 36.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.03e+03     |
# |    ep_rew_mean          | 461          |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 330          |
# |    time_elapsed         | 4349         |
# |    total_timesteps      | 675840       |
# | train/                  |              |
# |    approx_kl            | 0.0054193055 |
# |    clip_fraction        | 0.181        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.000273    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.39         |
# |    n_updates            | 3290         |
# |    policy_gradient_loss | -0.00536     |
# |    value_loss           | 23.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.03e+03    |
# |    ep_rew_mean          | 461         |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 331         |
# |    time_elapsed         | 4362        |
# |    total_timesteps      | 677888      |
# | train/                  |             |
# |    approx_kl            | 0.004231492 |
# |    clip_fraction        | 0.0959      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.00428     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.5        |
# |    n_updates            | 3300        |
# |    policy_gradient_loss | -0.00471    |
# |    value_loss           | 57.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.03e+03     |
# |    ep_rew_mean          | 464          |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 332          |
# |    time_elapsed         | 4376         |
# |    total_timesteps      | 679936       |
# | train/                  |              |
# |    approx_kl            | 0.0069259065 |
# |    clip_fraction        | 0.154        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00188     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.67         |
# |    n_updates            | 3310         |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 8.05         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.03e+03     |
# |    ep_rew_mean          | 464          |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 333          |
# |    time_elapsed         | 4389         |
# |    total_timesteps      | 681984       |
# | train/                  |              |
# |    approx_kl            | 0.0037629798 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00495     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13           |
# |    n_updates            | 3320         |
# |    policy_gradient_loss | -0.00581     |
# |    value_loss           | 33.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.03e+03    |
# |    ep_rew_mean          | 464         |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 334         |
# |    time_elapsed         | 4402        |
# |    total_timesteps      | 684032      |
# | train/                  |             |
# |    approx_kl            | 0.005080644 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00176     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.4        |
# |    n_updates            | 3330        |
# |    policy_gradient_loss | -0.00417    |
# |    value_loss           | 23.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.03e+03    |
# |    ep_rew_mean          | 463         |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 335         |
# |    time_elapsed         | 4415        |
# |    total_timesteps      | 686080      |
# | train/                  |             |
# |    approx_kl            | 0.006745713 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.00539     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.4        |
# |    n_updates            | 3340        |
# |    policy_gradient_loss | -0.00478    |
# |    value_loss           | 30.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.03e+03    |
# |    ep_rew_mean          | 463         |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 336         |
# |    time_elapsed         | 4428        |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.004407558 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.00293     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.99        |
# |    n_updates            | 3350        |
# |    policy_gradient_loss | -0.00448    |
# |    value_loss           | 23.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.03e+03     |
# |    ep_rew_mean          | 463          |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 337          |
# |    time_elapsed         | 4441         |
# |    total_timesteps      | 690176       |
# | train/                  |              |
# |    approx_kl            | 0.0058122594 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.00499      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.8         |
# |    n_updates            | 3360         |
# |    policy_gradient_loss | -0.00359     |
# |    value_loss           | 82.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.03e+03     |
# |    ep_rew_mean          | 463          |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 338          |
# |    time_elapsed         | 4454         |
# |    total_timesteps      | 692224       |
# | train/                  |              |
# |    approx_kl            | 0.0073981676 |
# |    clip_fraction        | 0.205        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.000654    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.68         |
# |    n_updates            | 3370         |
# |    policy_gradient_loss | -0.00306     |
# |    value_loss           | 8            |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.06e+03    |
# |    ep_rew_mean          | 471         |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 339         |
# |    time_elapsed         | 4466        |
# |    total_timesteps      | 694272      |
# | train/                  |             |
# |    approx_kl            | 0.008528294 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.0017     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.03        |
# |    n_updates            | 3380        |
# |    policy_gradient_loss | -0.000745   |
# |    value_loss           | 8.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.06e+03    |
# |    ep_rew_mean          | 471         |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 340         |
# |    time_elapsed         | 4480        |
# |    total_timesteps      | 696320      |
# | train/                  |             |
# |    approx_kl            | 0.009647576 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.00256     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 3390        |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 45.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.06e+03    |
# |    ep_rew_mean          | 471         |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 341         |
# |    time_elapsed         | 4493        |
# |    total_timesteps      | 698368      |
# | train/                  |             |
# |    approx_kl            | 0.004346504 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.00077    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.7        |
# |    n_updates            | 3400        |
# |    policy_gradient_loss | -0.00503    |
# |    value_loss           | 53.8        |
# -----------------------------------------
# Eval num_timesteps=700000, episode_reward=44.00 +/- 0.00
# Episode length: 4365.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 4.36e+03    |
# |    mean_reward          | 44          |
# | time/                   |             |
# |    total timesteps      | 700000      |
# | train/                  |             |
# |    approx_kl            | 0.004898954 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.00165     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 3410        |
# |    policy_gradient_loss | -0.0045     |
# |    value_loss           | 29.9        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.06e+03 |
# |    ep_rew_mean     | 471      |
# | time/              |          |
# |    fps             | 155      |
# |    iterations      | 342      |
# |    time_elapsed    | 4515     |
# |    total_timesteps | 700416   |
# ---------------------------------

# %%
env.reset()
eval_env.reset()

#instancia o algoritmo de aprendizagem
model = DQN('MlpPolicy', env, verbose=1,batch_size=128, buffer_size=10000,gradient_steps=1,exploration_fraction=0.1,create_eval_env=True,tensorboard_log="/tmp/stable-baselines/BeamRiderNoFrameskip-v4/custon2_dqn")

#treina o algoritmo
model.learn(total_timesteps=700000,eval_env=eval_env,eval_freq=175000, n_eval_episodes=1)

model.save("modelos/qdn/recigio_beamrider_700k")
del model
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to /tmp/stable-baselines/BeamRiderNoFrameskip-v4/custon2_dqn\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.71e+03 |
# |    ep_rew_mean      | 363      |
# |    exploration rate | 0.69     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1021     |
# |    time_elapsed     | 22       |
# |    total timesteps  | 22823    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.38e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration rate | 0.416    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1026     |
# |    time_elapsed     | 41       |
# |    total timesteps  | 43023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.57e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration rate | 0.093    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 311      |
# |    time_elapsed     | 214      |
# |    total timesteps  | 66829    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000825 |
# |    n_updates        | 4207     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.84e+03 |
# |    ep_rew_mean      | 393      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 193      |
# |    time_elapsed     | 483      |
# |    total timesteps  | 93497    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.339    |
# |    n_updates        | 10874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.8e+03  |
# |    ep_rew_mean      | 398      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 162      |
# |    time_elapsed     | 712      |
# |    total timesteps  | 116025   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.339    |
# |    n_updates        | 16506    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.69e+03 |
# |    ep_rew_mean      | 402      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 149      |
# |    time_elapsed     | 914      |
# |    total timesteps  | 136677   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000115 |
# |    n_updates        | 21669    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.82e+03 |
# |    ep_rew_mean      | 407      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 138      |
# |    time_elapsed     | 1175     |
# |    total timesteps  | 162955   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000149 |
# |    n_updates        | 28238    |
# ----------------------------------
# Eval num_timesteps=175000, episode_reward=176.00 +/- 0.00
# Episode length: 7923.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 7.92e+03 |
# |    mean_reward      | 176      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 175000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000219 |
# |    n_updates        | 31249    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.07e+03 |
# |    ep_rew_mean      | 425      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 128      |
# |    time_elapsed     | 1506     |
# |    total timesteps  | 194146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000227 |
# |    n_updates        | 36036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.2e+03  |
# |    ep_rew_mean      | 429      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 124      |
# |    time_elapsed     | 1795     |
# |    total timesteps  | 223256   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.34     |
# |    n_updates        | 43313    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.17e+03 |
# |    ep_rew_mean      | 425      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 121      |
# |    time_elapsed     | 2030     |
# |    total timesteps  | 246799   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000248 |
# |    n_updates        | 49199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.13e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 119      |
# |    time_elapsed     | 2261     |
# |    total timesteps  | 269723   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.34     |
# |    n_updates        | 54930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.1e+03  |
# |    ep_rew_mean      | 410      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 117      |
# |    time_elapsed     | 2495     |
# |    total timesteps  | 292791   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000216 |
# |    n_updates        | 60697    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.06e+03 |
# |    ep_rew_mean      | 411      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 116      |
# |    time_elapsed     | 2715     |
# |    total timesteps  | 315189   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000182 |
# |    n_updates        | 66297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.95e+03 |
# |    ep_rew_mean      | 405      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 115      |
# |    time_elapsed     | 2887     |
# |    total timesteps  | 332992   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000264 |
# |    n_updates        | 70747    |
# ----------------------------------
# Eval num_timesteps=350000, episode_reward=572.00 +/- 0.00
# Episode length: 8110.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 8.11e+03 |
# |    mean_reward      | 572      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 350000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000249 |
# |    n_updates        | 74999    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.89e+03 |
# |    ep_rew_mean      | 401      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 114      |
# |    time_elapsed     | 3095     |
# |    total timesteps  | 353182   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.34     |
# |    n_updates        | 75795    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.84e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 113      |
# |    time_elapsed     | 3293     |
# |    total timesteps  | 373828   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000146 |
# |    n_updates        | 80956    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.79e+03 |
# |    ep_rew_mean      | 389      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 112      |
# |    time_elapsed     | 3484     |
# |    total timesteps  | 393462   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000154 |
# |    n_updates        | 85865    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.71e+03 |
# |    ep_rew_mean      | 381      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 112      |
# |    time_elapsed     | 3655     |
# |    total timesteps  | 411286   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000118 |
# |    n_updates        | 90321    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.69e+03 |
# |    ep_rew_mean      | 378      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 111      |
# |    time_elapsed     | 3860     |
# |    total timesteps  | 432116   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000179 |
# |    n_updates        | 95528    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.67e+03 |
# |    ep_rew_mean      | 378      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 111      |
# |    time_elapsed     | 4079     |
# |    total timesteps  | 453726   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000221 |
# |    n_updates        | 100931   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.62e+03 |
# |    ep_rew_mean      | 376      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 110      |
# |    time_elapsed     | 4254     |
# |    total timesteps  | 471750   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000226 |
# |    n_updates        | 105437   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.58e+03 |
# |    ep_rew_mean      | 372      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 110      |
# |    time_elapsed     | 4445     |
# |    total timesteps  | 491173   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.338    |
# |    n_updates        | 110293   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.57e+03 |
# |    ep_rew_mean      | 368      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 109      |
# |    time_elapsed     | 4660     |
# |    total timesteps  | 512563   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000272 |
# |    n_updates        | 115640   |
# ----------------------------------
# Eval num_timesteps=525000, episode_reward=264.00 +/- 0.00
# Episode length: 5361.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 5.36e+03 |
# |    mean_reward      | 264      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 525000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000387 |
# |    n_updates        | 118749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.57e+03 |
# |    ep_rew_mean      | 373      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 109      |
# |    time_elapsed     | 4894     |
# |    total timesteps  | 534748   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000263 |
# |    n_updates        | 121186   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.54e+03 |
# |    ep_rew_mean      | 367      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 108      |
# |    time_elapsed     | 5086     |
# |    total timesteps  | 553624   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000284 |
# |    n_updates        | 125905   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.57e+03 |
# |    ep_rew_mean      | 368      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 108      |
# |    time_elapsed     | 5346     |
# |    total timesteps  | 579794   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000719 |
# |    n_updates        | 132448   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.6e+03  |
# |    ep_rew_mean      | 367      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 108      |
# |    time_elapsed     | 5574     |
# |    total timesteps  | 603316   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000485 |
# |    n_updates        | 138328   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.59e+03 |
# |    ep_rew_mean      | 372      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 107      |
# |    time_elapsed     | 5803     |
# |    total timesteps  | 626220   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000416 |
# |    n_updates        | 144054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.53e+03 |
# |    ep_rew_mean      | 367      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 107      |
# |    time_elapsed     | 6005     |
# |    total timesteps  | 646322   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000398 |
# |    n_updates        | 149080   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.48e+03 |
# |    ep_rew_mean      | 360      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 107      |
# |    time_elapsed     | 6180     |
# |    total timesteps  | 663616   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000291 |
# |    n_updates        | 153403   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.45e+03 |
# |    ep_rew_mean      | 353      |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 107      |
# |    time_elapsed     | 6359     |
# |    total timesteps  | 681625   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.336    |
# |    n_updates        | 157906   |
# ----------------------------------
# Eval num_timesteps=700000, episode_reward=0.00 +/- 0.00
# Episode length: 400000.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4e+05    |
# |    mean_reward      | 0        |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 700000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000516 |
# |    n_updates        | 162499   |
# ----------------------------------
# c:\xampp\htdocs\posfurb\aprendizadodemaquina\python\.env\lib\site-packages\stable_baselines3\common\save_util.py:276: UserWarning: Path 'modelos\qdn' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %% [markdown]
# #### Testando novos resultados

# %%
import gym
import time
from stable_baselines3 import A2C,PPO,DQN
from stable_baselines3.common.sb2_compat.rmsprop_tf_like import RMSpropTFLike

#carrega o ambiente
env = gym.make('BeamRiderNoFrameskip-v4')

model = A2C.load("modelos/a2c/recigio_beamrider_700k", env=env)

# importando biblioteca de avaliação e avaliando por 10 episodios
from stable_baselines3.common.evaluation import evaluate_policy

mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10, render=True)

print(mean_reward)
print(std_reward)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# 756.0
# 0.0

# %%
# O algoritmo achou um lugar que considerou mais ideal para se proteger dos tiros e atingir alguns inimigos
# ao invés de se movimenntar

# %%
import gym
import time
from stable_baselines3 import A2C,PPO,DQN
from stable_baselines3.common.sb2_compat.rmsprop_tf_like import RMSpropTFLike

#carrega o ambiente
env = gym.make('BeamRiderNoFrameskip-v4')

model = PPO.load("modelos/ppo/recigio_beamrider_700k", env=env)

# importando biblioteca de avaliação e avaliando por 10 episodios
from stable_baselines3.common.evaluation import evaluate_policy

mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10, render=True)

print(mean_reward)
print(std_reward)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# c:\xampp\htdocs\posfurb\aprendizadodemaquina\python\.env\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Não é possível alterar o modo de thread depois de o mesmo estar definido
#   warnings.warn(str(err))
# 176.0
# 0.0

# %%
# tentou achar um padrão de movimentacao que fizesse mais pontos, sem realmente observar os inimigos

# %%
import gym
import time
from stable_baselines3 import A2C,PPO,DQN
from stable_baselines3.common.sb2_compat.rmsprop_tf_like import RMSpropTFLike

#carrega o ambiente
env = gym.make('BeamRiderNoFrameskip-v4')

model = DQN.load("modelos/qdn/recigio_beamrider_700k", env=env)

# importando biblioteca de avaliação e avaliando por 10 episodios
from stable_baselines3.common.evaluation import evaluate_policy

mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10, render=True)

print(mean_reward)
print(std_reward)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# 39.6
# 60.4899991734171

# %%
#um resultado um pouco melhor que o ppo

# %% [markdown]
# ### Resultados

# %%
# Os resultados com 700k se mostraram um pouco melhores. Conteudo, para acalnsar resultados melhores, também,
# foram atualizados alguns parametros parametrizados. Me parece que esse cenário em especifico precisa de um.
# tunning melhor. Vendo agora, talvez o problema não seja exatamente overfit, mas parametrização.
# Também, me parece que seria necessário bem mais etapas de treinamento.

# %% [markdown]
# ![mean_reward](graficos/700k_1.png)

# %% [markdown]
# ![mean_reward](graficos/700k_2.png)

# %% [markdown]
# ### Treinando utilizando modelos RL Baselines3 Zoooo

# %%
# Devido a algum bug, apagou os relatorios de execução dos treinamentos.

# %%
# %cd rl-baselines3-zoo/
# Out:
# C:\xampp\htdocs\posfurb\reinforcementlearning\rl-baselines3-zoo

# %% [markdown]
# #### A2C - Treinamento com 2M de steps

# %%
# !python train.py --algo a2c --env BeamRiderNoFrameskip-v4 --tensorboard-log /tmp/stable-baselines/ -n 2000000 --save-freq 200000 --eval-freq 200000 --eval-episodes 10 --n-eval-envs 10

# %% [markdown]
# #### PPO - Treinamento com 2M de steps

# %%
#devido a um bug ele escreveu metade em cada celula
# !python train.py --algo ppo --env BeamRiderNoFrameskip-v4 --tensorboard-log /tmp/stable-baselines/ -n 2000000 --save-freq 200000 --eval-freq 200000 --eval-episodes 10 --n-eval-envs 10

# %% [markdown]
# #### DQN - Treinamento com 2M de steps

# %%
# !python train.py --algo dqn --env BeamRiderNoFrameskip-v4 --tensorboard-log /tmp/stable-baselines/ -n 2000000 --save-freq 200000 --eval-freq 200000 --eval-episodes 10 --n-eval-envs 10

# %% [markdown]
# #### Visualização dos resultados - Utilizando a biblioteca enjoy apontando pra pasta de saida dos treinamentos

# %%
# !python enjoy.py --algo a2c --env BeamRiderNoFrameskip-v4 --folder logs/ -n 5000

# %%
# !python enjoy.py --algo ppo --env BeamRiderNoFrameskip-v4 --folder logs/ -n 5000

# %%
# !python enjoy.py --algo dqn --env BeamRiderNoFrameskip-v4 --folder logs/ -n 5000

# %%
# Os resultados foram bons, não ótimos, a ia consegue algum sucesso. Parece um pouco aleatorio os movimentos,
# acredito que devido a complexidade, precisava de mais treinamento. 
# O agente pronto da biblioteca, performa bem melhor.

# %% [markdown]
# ![mean_reward ](graficos/Zoo_11.png)

# %% [markdown]
# ![mean_reward](graficos/Zoo_11.png)

# %% [markdown]
# ![mean_reward](graficos/Zoo_22.png)

# %% [markdown]
# # Resultados

# %% [markdown]
# ## Tabela comparativa

# %%
import pandas as pd
data = [
        #analise
        ['A2C', '2M',0,0], 
        ['A2C', '700k',756,0], 
        ['A2C ZOO', '700k',578,'NA'], 
        ['PPO', '2M',0,0], 
        ['PPO', '700k',176,0], 
        ['PPO ZOO', '700k',649,'NA'],
        ['DQN', '2M',44,0], 
        ['DQN', '700k',39,60], 
        ['DQN ZOO', '700k',3432,'NA']
        # modelo 1
       ]
  
# Create the pandas DataFrame
df = pd.DataFrame(data, columns = ['Algoritmo', 'TimeSteps','mean_reward','std_reward'])
  
# print dataframe.
df.sort_values(by=['mean_reward'], ascending=False)
# Out:
#   Algoritmo TimeSteps  mean_reward std_reward
# 8   DQN ZOO      700k         3432         NA
# 1       A2C      700k          756          0
# 5   PPO ZOO      700k          649         NA
# 2   A2C ZOO      700k          578         NA
# 4       PPO      700k          176          0
# 6       DQN        2M           44          0
# 7       DQN      700k           39         60
# 0       A2C        2M            0          0
# 3       PPO        2M            0          0

# %%
# Comparativamente os resultados do zoo parecem muito melhor tunados, numa mesma quantidade de timesptep.
# Talvez seja alguma parametrização ou configuração minha que falhou, mas acredito que não.
# Os algoritmos que eu treinei, tentavam encontrar um ponto otimo no cenário para ficarem parados, enquanto
# os algoritmos do zoom tentam se mover observando os inimigos. Acredito que que meus algoritmos estão empacando
# em algum maximo gradiente ou treinando com poucas etapas. Com precisei fazer vários experimentos, não
# tive tempo de treinar com mais de 2M de timesteps os modelos. Demoram em média 3 ou 4 horas cada um.
# Também, me parece que o DQN, baseado em Q-Learning parece o algoritmo mais promissor.

# %% [markdown]
# ## Melhores resultados A2C e DQN ZOO - Videos

# %%
import gym
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv
from stable_baselines3 import A2C,PPO,DQN

#carrega o ambiente
env_model = gym.make('BeamRiderNoFrameskip-v4')
model = A2C.load("modelos/a2c/recigio_beamrider_700k", env=env_model)

env_id = 'BeamRiderNoFrameskip-v4'
video_folder = 'videos/'
video_length = 3500

env = DummyVecEnv([lambda: gym.make(env_id)])
obs = env.reset()

# Record the video starting at the first step
env = VecVideoRecorder(env, video_folder,
                       record_video_trigger=lambda x: x == 0, video_length=video_length,
                       name_prefix="random-agent-{}".format(env_id))

env.reset()
for _ in range(video_length + 1):
  action, _states = model.predict(obs, deterministic=True)
  obs, rewards, done, info = env.step(action)
# Save the video
env.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Saving video to C:\xampp\htdocs\posfurb\reinforcementlearning\videos\random-agent-BeamRiderNoFrameskip-v4-step-0-to-step-3500.mp4

# %%
# %cd rl-baselines3-zoo/
# Out:
# C:\xampp\htdocs\posfurb\reinforcementlearning\rl-baselines3-zoo

# %%
# !python -m utils.record_video --algo dqn --env BeamRiderNoFrameskip-v4 --folder logs/ -n 3500
# Out:
# Loading latest experiment, id=1
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Saving video to C:\xampp\htdocs\posfurb\reinforcementlearning\rl-baselines3-zoo\logs\dqn\BeamRiderNoFrameskip-v4_1\videos\final-model-dqn-BeamRiderNoFrameskip-v4-step-0-to-step-3500.mp4
# C:\xampp\htdocs\posfurb\aprendizadodemaquina\python\.env\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Não é possível alterar o modo de thread depois de o mesmo estar definido
#   warnings.warn(str(err))
# Exception ignored in: <function VecVideoRecorder.__del__ at 0x00000234054FC5E0>
# Traceback (most recent call last):
#   File "C:\xampp\htdocs\posfurb\aprendizadodemaquina\python\.env\lib\site-packages\stable_baselines3\common\vec_env\vec_video_recorder.py", line 113, in __del__
#   File "C:\xampp\htdocs\posfurb\aprendizadodemaquina\python\.env\lib\site-packages\stable_baselines3\common\vec_env\vec_video_recorder.py", line 109, in close
# AttributeError: 'NoneType' object has no attribute 'close'

# %%
from IPython.display import Video
# %cd ..
# Out:
# C:\xampp\htdocs\posfurb\reinforcementlearning

# %% [markdown]
# ### DQN ZOO Video

# %%
Video("videos/final-model-dqn-BeamRiderNoFrameskip-v4-step-0-to-step-3500.mp4")
# Out:
# <video src="videos/final-model-dqn-BeamRiderNoFrameskip-v4-step-0-to-step-3500.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### A2C Video

# %%
Video("videos/random-agent-BeamRiderNoFrameskip-v4-step-0-to-step-3500.mp4")
# Out:
# <video src="videos/random-agent-BeamRiderNoFrameskip-v4-step-0-to-step-3500.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
